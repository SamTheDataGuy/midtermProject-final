# %%
#Google Places API notebook

import pandas as pd
import requests
import os

# %%
# Retreiving API key from environment variable
key = os.environ.get('api_key_places')

# %%
# For Sam's API key, comment out
from dotenv import load_dotenv
load_dotenv()
key = os.getenv('YELP_API_KEY2')

# %%
# Importing Yelp hotels dataframe

df_hotels = pd.read_csv('yelp_hotels.csv')
df_hotels.head()
# Out:
#                        id                                              alias  \
# 0  yeesT9W64tpVq5Gcae18Sg         delta-hotels-by-marriott-toronto-toronto-2
# 1  kKnGY0Xj7dG4ubjrbygynw  residence-inn-by-marriott-toronto-downtown-tor...
# 2  XHrPQKUTJXJGPH9etKUYUw     courtyard-by-marriott-toronto-downtown-toronto
# 3  zYRBRfYuq_6x-wNKa8NqrA                           le-germain-hotel-toronto
# 4  PCkJAv7WQJ08C1RA6ilqWA                            1-hotel-toronto-toronto
#
#                                          name  \
# 0            Delta Hotels by Marriott Toronto
# 1  Residence Inn by Marriott Toronto Downtown
# 2      Courtyard by Marriott Toronto Downtown
# 3                            Le Germain Hotel
# 4                             1 Hotel Toronto
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/TRWtlS...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/PFaLls...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/d6S6ga...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/m1977c...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/abOBDo...      False
#
#                                                  url  review_count categories  \
# 0  https://www.yelp.com/biz/delta-hotels-by-marri...           161     hotels
# 1  https://www.yelp.com/biz/residence-inn-by-marr...            95     hotels
# 2  https://www.yelp.com/biz/courtyard-by-marriott...           152     hotels
# 3  https://www.yelp.com/biz/le-germain-hotel-toro...            55     hotels
# 4  https://www.yelp.com/biz/1-hotel-toronto-toron...             5     hotels
#
#    rating transactions  ... coordinates.latitude  coordinates.longitude  \
# 0     4.0           []  ...            43.643069             -79.383865
# 1     4.0           []  ...            43.644790             -79.390530
# 2     3.0           []  ...            43.662410             -79.383149
# 3     4.5           []  ...            43.645751             -79.391025
# 4     5.0           []  ...            43.642826             -79.401439
#
#          location.address1  location.address2  location.address3  \
# 0   75 Lower Simcoe Street                NaN                NaN
# 1  255 Wellington Street W                NaN                NaN
# 2         475 Yonge Street                NaN                NaN
# 3         30 Mercer Street                NaN                NaN
# 4  550 Wellington Street W                NaN                NaN
#
#    location.city location.zip_code location.country location.state  \
# 0        Toronto           M5J 3A6               CA             ON
# 1        Toronto           M5V 3P9               CA             ON
# 2        Toronto           M4Y 1X7               CA             ON
# 3        Toronto           M5V 1H3               CA             ON
# 4        Toronto           M5V 2V4               CA             ON
#
#                             location.display_address
# 0  ['75 Lower Simcoe Street', 'Toronto, ON M5J 3A...
# 1  ['255 Wellington Street W', 'Toronto, ON M5V 3...
# 2  ['475 Yonge Street', 'Toronto, ON M4Y 1X7', 'C...
# 3  ['30 Mercer Street', 'Toronto, ON M5V 1H3', 'C...
# 4  ['550 Wellington Street W', 'Toronto, ON M5V 2...
#
# [5 rows x 24 columns]

# %%
# Viewing columns

df_hotels.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address'],
#       dtype='object')

# %%
# Deciding which columns to keep

df_hotels = df_hotels[['id', 'name', 'review_count',
       'categories', 'rating', 'price', 'distance', 'coordinates.latitude',
       'coordinates.longitude', 'location.address1',
       'location.city', 'location.zip_code',
       'location.country', 'location.state', 'location.display_address']]

# %%
# Renaming columns

df_hotels.columns = ['hotel_id', 'hotel_name', 'hotel_review_count',
       'hotel_categories', 'hotel_rating', 'hotel_price', 'hotel_distance', 'hotel_latitude',
       'hotel_longitude', 'hotel_address1', 
       'hotel_city', 'hotel_zip_code',
       'hotel_country', 'hotel_state', 'hotel_display_address']

# %%
# Definging the function to find all POI's of a specific category within a set distance from any hotels, using the Yelp API again

def find_POI_yelp(hotel_ids,latitudes,longitudes,radius,limit,categories):
    
    #fields = 'fsq_id,name,rating,popularity,price'
    list_POI = []
    
    # Find all POI's within 1000m of each bike station.  This will return one column with station_id and one column containing lists of POI's.
    for hotel_id,lat,long in zip(hotel_ids,latitudes,longitudes):
        url = 'https://api.yelp.com/v3/businesses/search'
        params = {
            'limit': limit,
            'latitude': lat,
            'longitude': long,
            'term': categories,
            'categories': categories,
            'radius': radius
        }

        headers = {"accept": "application/json","Authorization": 'bearer ' + key}
        response = requests.get(url, headers=headers,params=params).json()['businesses']
        list_POI.append([hotel_id,response])
    
    # convert to dataframe
    df = pd.DataFrame(list_POI,columns=['hotel_id','businesses'])

    # create 1 row for each match of bike station to POI.  There are duplicates of both bike stations and POI's, but each matchup is unique.
    df = df.explode('businesses').reset_index(drop=True) 
    df = pd.concat([df,pd.json_normalize(df['businesses'])],axis=1).drop('businesses',axis=1)
    
    return df
    #return requests.get(url, headers=headers,params=params).json()#['businesses']

# %%
# Running the function to find all POI's within a certain radius of every hotel

n = 1 # number of hotels to use
r = 150 # radius in metres
limit = 20 # max number of POI's to return for each hotel
categories = 'restaurants' # POI description

df = df_hotels.head(n)

df_POI = find_POI_yelp(df['hotel_id'],df['hotel_latitude'],df['hotel_longitude'],r,limit,categories)

# %%
df_POI.shape
# Out:
# (15, 25)

# %%
df_POI.head()
# Out:
#                  hotel_id                      id  \
# 0  yeesT9W64tpVq5Gcae18Sg  9eu2lQMROTKdrPyGkwZLYw
# 1  yeesT9W64tpVq5Gcae18Sg  x0MaTw6He1w_1nddeSJU2Q
# 2  yeesT9W64tpVq5Gcae18Sg  D1lAVtlav4atQTJnIvtcpw
# 3  yeesT9W64tpVq5Gcae18Sg  9-Lipa9HiHL_EAfeDfPq1g
# 4  yeesT9W64tpVq5Gcae18Sg  qAbBXmszDBJ4iZ8jdqeamQ
#
#                            alias                name  \
# 0       soco-kitchen-bar-toronto  SOCO Kitchen + Bar
# 1       the-roof-at-soco-toronto    The Roof at SOCO
# 2       taverna-mercatto-toronto    Taverna Mercatto
# 3     busters-sea-cove-toronto-3   Buster's Sea Cove
# 4  aroma-espresso-bar-toronto-47  Aroma Espresso Bar
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/85--in...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/gF-WNQ...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/I8Guuj...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/4jrvkf...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/ZQEt3h...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/soco-kitchen-bar-toro...           236
# 1  https://www.yelp.com/biz/the-roof-at-soco-toro...            17
# 2  https://www.yelp.com/biz/taverna-mercatto-toro...           229
# 3  https://www.yelp.com/biz/busters-sea-cove-toro...            33
# 4  https://www.yelp.com/biz/aroma-espresso-bar-to...            39
#
#                                           categories  rating  ...  \
# 0  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     3.5  ...
# 1  [{'alias': 'newcanadian', 'title': 'Canadian (...     4.0  ...
# 2         [{'alias': 'italian', 'title': 'Italian'}]     3.5  ...
# 3  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5  ...
# 4             [{'alias': 'cafes', 'title': 'Cafes'}]     3.5  ...
#
#   coordinates.latitude coordinates.longitude       location.address1  \
# 0            43.642653            -79.383847  75 Lower Simcoe Street
# 1            43.643030            -79.383790  75 Lower Simcoe Street
# 2            43.642672            -79.382760   120 Bremner Boulevard
# 3            43.642566            -79.383051   120 Bremner Boulevard
# 4            43.642386            -79.383637   137 Bremner Boulevard
#
#   location.address2  location.address3  location.city  location.zip_code  \
# 0                                             Toronto            M5J 3A6
# 1      Fourth Floor                           Toronto            M5J 3A6
# 2                                             Toronto            M5J 3A6
# 3                                             Toronto            M5J 0A1
# 4                                 None        Toronto            M5J 3A7
#
#   location.country location.state  \
# 0               CA             ON
# 1               CA             ON
# 2               CA             ON
# 3               CA             ON
# 4               CA             ON
#
#                             location.display_address
# 0  [75 Lower Simcoe Street, Toronto, ON M5J 3A6, ...
# 1  [75 Lower Simcoe Street, Fourth Floor, Toronto...
# 2  [120 Bremner Boulevard, Toronto, ON M5J 3A6, C...
# 3  [120 Bremner Boulevard, Toronto, ON M5J 0A1, C...
# 4  [137 Bremner Boulevard, Toronto, ON M5J 3A7, C...
#
# [5 rows x 25 columns]

# %%
# Viewing columns in df_POI

df_POI.columns
# Out:
# Index(['hotel_id', 'id', 'alias', 'name', 'image_url', 'is_closed', 'url',
#        'review_count', 'categories', 'rating', 'transactions', 'price',
#        'phone', 'display_phone', 'distance', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address'],
#       dtype='object')

# %%
# Deciding which columns to keep in df_POI

df_POI = df_POI[['hotel_id', 'id', 'name',
       'review_count', 'categories', 'rating', 'transactions', 'price',
       'distance', 'coordinates.latitude',
       'coordinates.longitude', 'location.address1', 
       'location.city', 'location.zip_code',
       'location.country', 'location.state', 'location.display_address']]

# %%
# Renaming columns in df_POI

df_POI.columns = ['hotel_id', 'poi_id', 'poi_name',
       'poi_review_count', 'poi_categories', 'poi_rating', 'poi_transactions', 'poi_price',
       'poi_distance', 'poi_latitude',
       'poi_longitude', 'poi_address1', 
       'poi_city', 'poi_zip_code',
       'poi_country', 'poi_state', 'poi_display_address']

# %%
# Creating new poi_price column that turns the number of dollar signs to integers

df_POI['poi_price_int'] = df_POI['poi_price'].str.len()

# %%
df_POI.head()
# Out:
#                  hotel_id                  poi_id            poi_name  \
# 0  yeesT9W64tpVq5Gcae18Sg  9eu2lQMROTKdrPyGkwZLYw  SOCO Kitchen + Bar
# 1  yeesT9W64tpVq5Gcae18Sg  x0MaTw6He1w_1nddeSJU2Q    The Roof at SOCO
# 2  yeesT9W64tpVq5Gcae18Sg  D1lAVtlav4atQTJnIvtcpw    Taverna Mercatto
# 3  yeesT9W64tpVq5Gcae18Sg  9-Lipa9HiHL_EAfeDfPq1g   Buster's Sea Cove
# 4  yeesT9W64tpVq5Gcae18Sg  qAbBXmszDBJ4iZ8jdqeamQ  Aroma Espresso Bar
#
#    poi_review_count                                     poi_categories  \
# 0               236  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 1                17  [{'alias': 'newcanadian', 'title': 'Canadian (...
# 2               229         [{'alias': 'italian', 'title': 'Italian'}]
# 3                33  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 4                39             [{'alias': 'cafes', 'title': 'Cafes'}]
#
#    poi_rating poi_transactions poi_price  poi_distance  poi_latitude  \
# 0         3.5               []        $$     46.260363     43.642653
# 1         4.0               []       NaN     11.736958     43.643030
# 2         3.5               []        $$     99.247399     43.642672
# 3         3.5               []        $$     86.123705     43.642566
# 4         3.5               []        $$     78.124941     43.642386
#
#    poi_longitude            poi_address1 poi_city poi_zip_code poi_country  \
# 0     -79.383847  75 Lower Simcoe Street  Toronto      M5J 3A6          CA
# 1     -79.383790  75 Lower Simcoe Street  Toronto      M5J 3A6          CA
# 2     -79.382760   120 Bremner Boulevard  Toronto      M5J 3A6          CA
# 3     -79.383051   120 Bremner Boulevard  Toronto      M5J 0A1          CA
# 4     -79.383637   137 Bremner Boulevard  Toronto      M5J 3A7          CA
#
#   poi_state                                poi_display_address  poi_price2  \
# 0        ON  [75 Lower Simcoe Street, Toronto, ON M5J 3A6, ...         2.0
# 1        ON  [75 Lower Simcoe Street, Fourth Floor, Toronto...         NaN
# 2        ON  [120 Bremner Boulevard, Toronto, ON M5J 3A6, C...         2.0
# 3        ON  [120 Bremner Boulevard, Toronto, ON M5J 0A1, C...         2.0
# 4        ON  [137 Bremner Boulevard, Toronto, ON M5J 3A7, C...         2.0
#
#    poi_price_int
# 0            2.0
# 1            NaN
# 2            2.0
# 3            2.0
# 4            2.0

# %%
# Creating a pivot table that groups df_POI by hotel_id and aggregates the means for price, rating, and review counts for the POI's nearby each hotel.  It also aggregates the count of POI's near each hotel.

pivot_poi = df_POI.pivot_table(index='hotel_id',values=['poi_review_count','poi_rating','poi_price2'],
                               aggfunc=['mean','count']).reset_index()

pivot_poi.columns = ['hotel_id','mean_poi_price2','mean_poi_rating','mean_poi_review_count','count_poi_price2','count_poi','count_poi_review_count']
pivot_poi = pivot_poi[['hotel_id','mean_poi_price2','mean_poi_rating','mean_poi_review_count','count_poi']]


pivot_poi.head()
# Out:
#                  hotel_id  mean_poi_price2  mean_poi_rating  \
# 0  yeesT9W64tpVq5Gcae18Sg              1.8         2.766667
#
#    mean_poi_review_count  count_poi
# 0              58.133333         15

# %%
# Merging df_hotles with pivot_poi

df_merge = df_hotels.merge(pivot_poi,on='hotel_id', how='left')
df_merge.head()
# Out:
#                  hotel_id                                  hotel_name  \
# 0  yeesT9W64tpVq5Gcae18Sg            Delta Hotels by Marriott Toronto
# 1  kKnGY0Xj7dG4ubjrbygynw  Residence Inn by Marriott Toronto Downtown
# 2  XHrPQKUTJXJGPH9etKUYUw      Courtyard by Marriott Toronto Downtown
# 3  zYRBRfYuq_6x-wNKa8NqrA                            Le Germain Hotel
# 4  PCkJAv7WQJ08C1RA6ilqWA                             1 Hotel Toronto
#
#    hotel_review_count hotel_categories  hotel_rating hotel_price  \
# 0                 161           hotels           4.0          $$
# 1                  95           hotels           4.0          $$
# 2                 152           hotels           3.0          $$
# 3                  55           hotels           4.5         $$$
# 4                   5           hotels           5.0         NaN
#
#    hotel_distance  hotel_latitude  hotel_longitude           hotel_address1  \
# 0     3623.820220       43.643069       -79.383865   75 Lower Simcoe Street
# 1     3320.732218       43.644790       -79.390530  255 Wellington Street W
# 2     1718.071430       43.662410       -79.383149         475 Yonge Street
# 3     3202.097393       43.645751       -79.391025         30 Mercer Street
# 4     3517.449544       43.642826       -79.401439  550 Wellington Street W
#
#    ... hotel_address3 hotel_city hotel_zip_code hotel_country hotel_state  \
# 0  ...            NaN    Toronto        M5J 3A6            CA          ON
# 1  ...            NaN    Toronto        M5V 3P9            CA          ON
# 2  ...            NaN    Toronto        M4Y 1X7            CA          ON
# 3  ...            NaN    Toronto        M5V 1H3            CA          ON
# 4  ...            NaN    Toronto        M5V 2V4            CA          ON
#
#                                hotel_display_address mean_poi_price2  \
# 0  ['75 Lower Simcoe Street', 'Toronto, ON M5J 3A...             1.8
# 1  ['255 Wellington Street W', 'Toronto, ON M5V 3...             NaN
# 2  ['475 Yonge Street', 'Toronto, ON M4Y 1X7', 'C...             NaN
# 3  ['30 Mercer Street', 'Toronto, ON M5V 1H3', 'C...             NaN
# 4  ['550 Wellington Street W', 'Toronto, ON M5V 2...             NaN
#
#    mean_poi_rating  mean_poi_review_count  count_poi
# 0         2.766667              58.133333       15.0
# 1              NaN                    NaN        NaN
# 2              NaN                    NaN        NaN
# 3              NaN                    NaN        NaN
# 4              NaN                    NaN        NaN
#
# [5 rows x 21 columns]

# %%
# Writing df_merge to a .csv file

df_merge.to_csv('hotel_and_restaurants.csv', index=False)
