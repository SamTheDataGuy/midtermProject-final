# %%
# !pip install xgboost
# Out:
# ...
#      --------------------------------------- 70.9/70.9 MB 21.1 MB/s eta 0:00:00
# ...

# %%
#Import Libraries
#Data Manipulation
import numpy as np
import pandas as pd

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#Models
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

#Metrics
from sklearn.metrics import r2_score

#Load Data
hotels_poi_data = pd.read_csv(r'C:\Users\nas76\Desktop\Github Projects\Google Places\midtermProject\hotels_and_POIs.csv')
#hotels_poi_data.set_index('hotel_id', inplace=True)
hotels_poi_data.head()
# Out:
#                  hotel_id                                  hotel_name  \
# 0  yeesT9W64tpVq5Gcae18Sg            Delta Hotels by Marriott Toronto
# 1  kKnGY0Xj7dG4ubjrbygynw  Residence Inn by Marriott Toronto Downtown
# 2  XHrPQKUTJXJGPH9etKUYUw      Courtyard by Marriott Toronto Downtown
# 3  zYRBRfYuq_6x-wNKa8NqrA                            Le Germain Hotel
# 4  PCkJAv7WQJ08C1RA6ilqWA                             1 Hotel Toronto
#
#    hotel_review_count hotel_categories  hotel_rating  hotel_price  \
# 0                 161           hotels           4.0     2.000000
# 1                  95           hotels           4.0     2.000000
# 2                 152           hotels           3.0     2.000000
# 3                  55           hotels           4.5     3.000000
# 4                   5           hotels           5.0     2.233577
#
#    hotel_distance  hotel_latitude  hotel_longitude           hotel_address1  \
# ...

# %%
hotels_poi_data.shape
# Out:
# (200, 19)

# %%
#Getting Information about the dataset
hotels_poi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   hotel_id               200 non-null    object
#  1   hotel_name             200 non-null    object
#  2   hotel_review_count     200 non-null    int64
#  3   hotel_categories       200 non-null    object
#  4   hotel_rating           200 non-null    float64
#  5   hotel_price            200 non-null    float64
#  6   hotel_distance         200 non-null    float64
#  7   hotel_latitude         200 non-null    float64
#  8   hotel_longitude        200 non-null    float64
#  9   hotel_address1         199 non-null    object
#  10  hotel_city             200 non-null    object
#  11  hotel_zip_code         198 non-null    object
#  12  hotel_country          200 non-null    object
#  13  hotel_state            200 non-null    object
# ...

# %%
#Acquiring information about the numeric data in the dataframe
hotels_poi_data.describe()
# Out:
#        hotel_review_count  hotel_rating  hotel_price  hotel_distance  \
# count          200.000000    200.000000   200.000000      200.000000
# mean            37.395000      3.085000     2.233577     7201.187792
# std             60.168432      1.022498     0.532962     6525.626332
# min              1.000000      1.000000     1.000000      247.153531
# 25%              4.750000      2.500000     2.000000     2428.790087
# 50%             12.000000      3.000000     2.233577     3458.521877
# 75%             40.000000      4.000000     2.233577    13915.531220
# max            423.000000      5.000000     4.000000    40434.031470
#
#        hotel_latitude  hotel_longitude  mean_poi_price  mean_poi_rating  \
# count      200.000000       200.000000      163.000000       176.000000
# mean        43.677119       -79.429909        1.963254         3.121525
# std          0.053112         0.090160        0.409329         0.634285
# ...

# %%
#Creating a boxplot
sns.boxplot(x ='hotel_rating', y ='hotel_price',data = hotels_poi_data)
# Out:
# <Axes: xlabel='hotel_rating', ylabel='hotel_price'>

# %%
#Creating a boxplot
sns.boxplot(x ='hotel_rating', y ='mean_poi_rating',data = hotels_poi_data)
# Out:
# <Axes: xlabel='hotel_rating', ylabel='mean_poi_rating'>

# %%
#Creating a linear model plot
sns.lmplot(x ='hotel_rating', y ='hotel_price', hue = 'hotel_categories', data = hotels_poi_data)

# %%
#Creating a scatter plot
sns.scatterplot(x ='hotel_rating', y ='hotel_price',data = hotels_poi_data)
# Out:
# <Axes: xlabel='hotel_rating', ylabel='hotel_price'>

# %%
#Creating a scatter plot
sns.scatterplot(x ='hotel_rating', y ='count_poi',data = hotels_poi_data)
# Out:
# <Axes: xlabel='hotel_rating', ylabel='count_poi'>

# %%
#Creating a scatter plot
sns.scatterplot(x ='hotel_price', y ='count_poi',data = hotels_poi_data)
# Out:
# <Axes: xlabel='hotel_price', ylabel='count_poi'>

# %%
#Creating a scatter plot
sns.scatterplot(y ='hotel_rating', x ='mean_poi_rating',data = hotels_poi_data)
# Out:
# <Axes: xlabel='mean_poi_rating', ylabel='hotel_rating'>
