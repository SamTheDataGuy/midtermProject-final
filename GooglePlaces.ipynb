# %%
#Google Places API notebook

import pandas as pd
import requests
import os

# %%
key = os.environ.get('api_key_places')

# %%
#Getting information on Hotels in toronto using google places api

#url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&key={api_key}"
url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query=hotels+in+toronto&key={key}"

response = requests.get(url)
response = response.json()
places_data = response['results']

df = pd.DataFrame(places_data)
df.head()
# Out:
#   business_status                                formatted_address  \
# 0     OPERATIONAL         1 King St W, Toronto, ON M5H 1A1, Canada
# 1     OPERATIONAL          14 York St, Toronto, ON M5J 0B1, Canada
# 2     OPERATIONAL   145 Richmond St W, Toronto, ON M5H 2L2, Canada
# 3     OPERATIONAL  650 1/2 Queen St W, Toronto, ON M6J 1E4, Canada
# 4     OPERATIONAL      100 Front St W, Toronto, ON M5J 1E3, Canada
#
#                                             geometry  \
# 0  {'location': {'lat': 43.6488726, 'lng': -79.37...
# 1  {'location': {'lat': 43.6420018, 'lng': -79.38...
# 2  {'location': {'lat': 43.6498523, 'lng': -79.38...
# 3  {'location': {'lat': 43.6468534, 'lng': -79.40...
# 4  {'location': {'lat': 43.6460303, 'lng': -79.38...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
#
#                                   icon_mask_base_uri  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                               name       opening_hours  \
# 0  One King West Hotel & Residence  {'open_now': True}
# 1                     Aaira Suites                 NaN
# 2                   Hilton Toronto                 NaN
# 3                   The Palmerston  {'open_now': True}
# 4              Fairmont Royal York                 NaN
#
#                                               photos  \
# 0  [{'height': 4931, 'html_attributions': ['<a hr...
# 1  [{'height': 4032, 'html_attributions': ['<a hr...
# 2  [{'height': 833, 'html_attributions': ['<a hre...
# 3  [{'height': 320, 'html_attributions': ['<a hre...
# 4  [{'height': 2048, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJG74DgzLL1IkRu7-_ro1TbdY
# 1  ChIJGWaDINU0K4gR1Kn67pB4z6E
# 2  ChIJJd9P-800K4gRvTdTqtNCmQw
# 3  ChIJAQDUzeY0K4gRTPpwFGajCsY
# 4  ChIJYY4qFdM0K4gRDydzDiP-VAE
#
#                                            plus_code  rating  \
# 0  {'compound_code': 'JJXC+GQ Toronto, Ontario', ...     4.4
# 1  {'compound_code': 'JJR9+Q9 Toronto, Ontario', ...     3.9
# 2  {'compound_code': 'JJX7+WQ Toronto, Ontario', ...     4.2
# 3  {'compound_code': 'JHWV+PC Toronto, Ontario', ...     3.1
# 4  {'compound_code': 'JJW9+CC Toronto, Ontario', ...     4.5
#
#                      reference  \
# 0  ChIJG74DgzLL1IkRu7-_ro1TbdY
# 1  ChIJGWaDINU0K4gR1Kn67pB4z6E
# 2  ChIJJd9P-800K4gRvTdTqtNCmQw
# 3  ChIJAQDUzeY0K4gRTPpwFGajCsY
# 4  ChIJYY4qFdM0K4gRDydzDiP-VAE
#
#                                                types  user_ratings_total
# 0        [lodging, point_of_interest, establishment]                4771
# 1        [lodging, point_of_interest, establishment]                  16
# 2        [lodging, point_of_interest, establishment]                4747
# 3        [lodging, point_of_interest, establishment]                 151
# 4  [lodging, restaurant, food, point_of_interest,...               10274

# %%
#df1 = pd.DataFrame(places_data, columns=['name', 'formatted_address', 'geometry', 'place_id', 'rating', 'types'])
# Extract the first word from 'types' as a separate column
#df1['types'] = df1['types'].apply(lambda x: x[0].split()[0])
#df1.head()

# %%
#I updated the code for hotels.com api to show hotels.
# we will need to edit regionNames column into "name of hotel" and only show name of the hotel name after 'fullname' and before the comma.
#
#

url = "https://hotels-com-provider.p.rapidapi.com/v2/regions"
querystring = {"domain": "CA", "query": "Toronto", "locale": "en_CA"}

headers = {
    "X-RapidAPI-Key": "PUT_YOUR_API_KEY_HERE",
    "X-RapidAPI-Host": "hotels-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json() 

hotel_data = data['data']
df_hotel = pd.DataFrame(hotel_data)
df_hotel = df_hotel[df_hotel['type'] == 'HOTEL']
df_hotel.head(25)
# Out:
#              @type index gaiaId   type  \
# 4  gaiaHotelResult     4    NaN  HOTEL
# 6  gaiaHotelResult     6    NaN  HOTEL
# 7  gaiaHotelResult     7    NaN  HOTEL
# 8  gaiaHotelResult     8    NaN  HOTEL
#
#                                          regionNames  \
# 4  {'fullName': 'Toronto Airport Marriott Hotel, ...
# 6  {'fullName': 'Comfort Inn & Conference Centre ...
# 7  {'fullName': 'Toronto Don Valley Hotel and Sui...
# 8  {'fullName': 'Sheraton Gateway Hotel In Toront...
#
#                                         essId  \
# 4  {'sourceName': 'LCM', 'sourceId': '16617'}
# 6   {'sourceName': 'LCM', 'sourceId': '6196'}
# 7   {'sourceName': 'LCM', 'sourceId': '8978'}
# 8   {'sourceName': 'LCM', 'sourceId': '4826'}
#
#                                   coordinates  \
# 4    {'lat': '43.68673', 'long': '-79.59388'}
# 6  {'lat': '43.699706', 'long': '-79.585279'}
# 7  {'lat': '43.725883', 'long': '-79.327073'}
# 8  {'lat': '43.686334', 'long': '-79.620642'}
#
#                       hierarchyInfo isMinorAirport hotelId cityId  \
# 4  {'country': {'isoCode3': 'CAN'}}            NaN   16617   4089
# 6  {'country': {'isoCode3': 'CAN'}}            NaN    6196   4089
# 7  {'country': {'isoCode3': 'CAN'}}            NaN    8978   4089
# 8  {'country': {'isoCode3': 'CAN'}}            NaN    4826   7954
#
#                                         hotelAddress
# 4  {'street': '901 Dixon Road', 'city': 'Toronto'...
# 6  {'street': '240 Belfield Road', 'city': 'Toron...
# 7  {'street': '175 Wynford Drive', 'city': 'Toron...
# 8  {'street': 'Terminal 3, Toronto AMF', 'city': ...

# %%
import requests

url = "https://hotels-com-provider.p.rapidapi.com/v2/domains"

headers = {
	"X-RapidAPI-Key": "PUT_YOUR_API_KEY_HERE",
	"X-RapidAPI-Host": "hotels-com-provider.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'AE': {'domain': 'AE', 'url': 'www.hotels.com', 'country_code': 'ARE', 'site_id': 310000033, 'tpid': 3100, 'eapid': 33, 'currency': 'USD', 'supported_locales': {'en_GB': {'key': 'en_GB', 'language_code': None, 'language_id': 2057}}}, 'AR': {'domain': 'AR', 'url': 'ar.hoteles.com', 'country_code': 'ARG', 'site_id': 301900003, 'tpid': 3019, 'eapid': 3, 'currency': 'ARS', 'supported_locales': {'es_AR': {'key': 'es_AR', 'language_code': 'es-AR', 'language_id': 11274}}}, 'AS': {'domain': 'AS', 'url': 'www.hotels.com', 'country_code': 'ASM', 'site_id': 300000034, 'tpid': 3200, 'eapid': 34, 'currency': 'USD', 'supported_locales': {'en_AS': {'key': 'en_AS', 'language_code': None, 'language_id': 4096}}}, 'AT': {'domain': 'AT', 'url': 'at.hotels.com', 'country_code': 'AUT', 'site_id': 300000020, 'tpid': 3180, 'eapid': 20, 'currency': 'EUR', 'supported_locales': {'de_AT': {'key': 'de_AT', 'language_code': 'de-AT', 'language_id': 1031}}}, 'AU': {'domain': 'AU', 'url': 'au.hotels.com', 'country_code': 'AUS', 'site_id': 300000035, 'tpid': 3201, 'eapid': 35, 'currency': 'AUD', 'supported_locales': {'en_AU': {'key': 'en_AU', 'language_code': None, 'language_id': 3081}}}, 'BE': {'domain': 'BE', 'url': 'be.hotels.com', 'country_code': 'BEL', 'site_id': 300000017, 'tpid': 4780, 'eapid': 17, 'currency': 'EUR', 'supported_locales': {'de_BE': {'key': 'de_BE', 'language_code': 'de-BE', 'language_id': 6151}, 'fr_BE': {'key': 'fr_BE', 'language_code': 'fr-BE', 'language_id': 2060}, 'nl_BE': {'key': 'nl_BE', 'language_code': 'nl-BE', 'language_id': 1043}}}, 'BR': {'domain': 'BR', 'url': 'www.hoteis.com', 'country_code': 'BRA', 'site_id': 301800003, 'tpid': 3018, 'eapid': 3, 'currency': 'BRL', 'supported_locales': {'pt_BR': {'key': 'pt_BR', 'language_code': None, 'language_id': 1046}}}, 'CA': {'domain': 'CA', 'url': 'ca.hotels.com', 'country_code': 'CAN', 'site_id': 300000002, 'tpid': 3002, 'eapid': 2, 'currency': 'CAD', 'supported_locales': {'en_CA': {'key': 'en_CA', 'language_code': 'en-CA', 'language_id': 4105}, 'fr_CA': {'key': 'fr_CA', 'language_code': 'fr', 'language_id': 3084}}}, 'CH': {'domain': 'CH', 'url': 'ch.hotels.com', 'country_code': 'CHE', 'site_id': 300000014, 'tpid': 3111, 'eapid': 14, 'currency': 'CHF', 'supported_locales': {'de_CH': {'key': 'de_CH', 'language_code': 'de-CH', 'language_id': 2055}, 'fr_CH': {'key': 'fr_CH', 'language_code': 'fr-CH', 'language_id': 4108}, 'it_CH': {'key': 'it_CH', 'language_code': 'it-CH', 'language_id': 2064}}}, 'CL': {'domain': 'CL', 'url': 'www.hoteles.com', 'country_code': 'CHL', 'site_id': 312800003, 'tpid': 3128, 'eapid': None, 'currency': 'CLP', 'supported_locales': {'es_CL': {'key': 'es_CL', 'language_code': 'es', 'language_id': 13322}}}, 'CN': {'domain': 'CN', 'url': 'www.hotels.cn', 'country_code': 'CHN', 'site_id': 300000042, 'tpid': 3208, 'eapid': 42, 'currency': 'CNY', 'supported_locales': {'zh_CN': {'key': 'zh_CN', 'language_code': 'zh-Hans', 'language_id': 2052}, 'en_US': {'key': 'en_US', 'language_code': 'en', 'language_id': 1033}}}, 'CO': {'domain': 'CO', 'url': 'co.hoteles.com', 'country_code': 'COL', 'site_id': 312700003, 'tpid': 3127, 'eapid': 3, 'currency': 'COP', 'supported_locales': {'es_CO': {'key': 'es_CO', 'language_code': 'es', 'language_id': 11274}}}, 'DE': {'domain': 'DE', 'url': 'de.hotels.com', 'country_code': 'DEU', 'site_id': 300000752, 'tpid': 3102, 'eapid': 752, 'currency': 'EUR', 'supported_locales': {'de_DE': {'key': 'de_DE', 'language_code': 'de', 'language_id': 1031}}}, 'DK': {'domain': 'DK', 'url': 'da.hotels.com', 'country_code': 'DNK', 'site_id': 300000013, 'tpid': 3110, 'eapid': 13, 'currency': 'DKK', 'supported_locales': {'da_DK': {'key': 'da_DK', 'language_code': None, 'language_id': 1030}}}, 'ES': {'domain': 'ES', 'url': 'es.hoteles.com', 'country_code': 'ESP', 'site_id': 300000008, 'tpid': 3104, 'eapid': 8, 'currency': 'EUR', 'supported_locales': {'es_ES': {'key': 'es_ES', 'language_code': None, 'language_id': 3082}}}, 'FI': {'domain': 'FI', 'url': 'fi.hot ...

# %%
#This is from another hotels api, although in the webpage it says the hotels api has prices, i dont see it in the output
#this is the link https://rapidapi.com/apidojo/api/hotels4

import requests
import pandas as pd
hotels_url = "https://hotels4.p.rapidapi.com/locations/v3/search"

querystring = {"q":"toronto","locale":"en_US","langid":"1033","siteid":"300000001"}

headers = {
	"X-RapidAPI-Key": "YOUR_API_KEY_HERE",
	"X-RapidAPI-Host": "hotels4.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

hotels_data = response.json() 
# Extract the relevant data from the JSON response
results = hotels_data['sr']


# Create a DataFrame using the extracted data
df_hotel = pd.DataFrame(results)
df_hotel.head()
# Out:
#               @type index   gaiaId          type  \
# 0  gaiaRegionResult     0     4089          CITY
# 1  gaiaRegionResult     1  6057934  NEIGHBORHOOD
# 2  gaiaRegionResult     2  5921113       AIRPORT
# 3  gaiaRegionResult     3  6262376  NEIGHBORHOOD
# 4   gaiaHotelResult     4      NaN         HOTEL
#
#                                          regionNames  \
# 0  {'fullName': 'Toronto, Ontario, Canada', 'shor...
# 1  {'fullName': 'Downtown Toronto, Toronto, Ontar...
# 2  {'fullName': 'Toronto, ON, Canada (YYZ-Pearson...
# 3  {'fullName': 'Toronto Entertainment District, ...
# 4  {'fullName': 'Toronto Airport Marriott Hotel, ...
#
#                                           essId  \
# 0     {'sourceName': 'GAI', 'sourceId': '4089'}
# 1  {'sourceName': 'GAI', 'sourceId': '6057934'}
# 2  {'sourceName': 'GAI', 'sourceId': '5921113'}
# 3  {'sourceName': 'GAI', 'sourceId': '6262376'}
# 4    {'sourceName': 'LCM', 'sourceId': '16617'}
#
#                                          coordinates  \
# 0         {'lat': '43.652845', 'long': '-79.383602'}
# 1  {'lat': '43.65518501505282', 'long': '-79.3802...
# 2           {'lat': '43.68146', 'long': '-79.61142'}
# 3         {'lat': '43.642662', 'long': '-79.388786'}
# 4           {'lat': '43.68673', 'long': '-79.59388'}
#
#                                        hierarchyInfo isMinorAirport hotelId  \
# 0  {'country': {'name': 'Canada', 'isoCode2': 'CA...            NaN     NaN
# 1  {'country': {'name': 'Canada', 'isoCode2': 'CA...            NaN     NaN
# 2  {'country': {'name': 'Canada', 'isoCode2': 'CA...          false     NaN
# 3  {'country': {'name': 'Canada', 'isoCode2': 'CA...            NaN     NaN
# 4                   {'country': {'isoCode3': 'CAN'}}            NaN   16617
#
#   cityId                                       hotelAddress
# 0    NaN                                                NaN
# 1    NaN                                                NaN
# 2    NaN                                                NaN
# 3    NaN                                                NaN
# 4   4089  {'street': '901 Dixon Road', 'city': 'Toronto'...
